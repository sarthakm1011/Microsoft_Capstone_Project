# %%
# SOME OTHER GOOD MODELS
# print 'LinearRegression'
# #print '-'*15 
# LR = LinearRegression()
# LR.fit(x_train,y_train)
# lr_pred = LR.predict(x_test)
# print mean_squared_error(lr_pred,y_test)
# print 'RMSE: ' + str(np.sqrt(mean_squared_error(lr_pred,y_test)))
# print 'Accuracy of Linear Regression is %s%%'%(LR.score(x_test,y_test)*100)
# print '='*60
# #71 Acc 
# #980 MSE


# print 'MLPRegressor'
# #print '-'*15
# NN = MLPRegressor(hidden_layer_sizes=200,batch_size=50,learning_rate='adaptive',alpha=30)
# NN.fit(x_train,y_train)
# print 'Accuracy of MLPRegressor is %s%%'%(NN.score(x_test,y_test)*100)

# test_nn = NN.predict(x_test)

# #Calculating root mean square error manually
# rmse = 0.0
# err  = 0.0
# for i in range(len(y_test)):  
#     err += (y_test[i]-test_nn[i])**2

# mean_err = err / len(y_test)

# rmse = np.sqrt(mean_err)
# print 'RMSE = %f' %rmse
# print '='*60

# %%
# from sklearn.ensemble import AdaBoostRegressor
# from sklearn.ensemble import BaggingRegressor
# from sklearn.ensemble import ExtraTreesRegressor
# from sklearn.ensemble import GradientBoostingRegressor
# from sklearn.kernel_ridge import KernelRidge
# from sklearn.linear_model import HuberRegressor
# from sklearn.linear_model import LogisticRegression
# from sklearn.naive_bayes import GaussianNB
# from sklearn.neural_network import MLPRegressor
# from sklearn.linear_model import TheilSenRegressor

# # Good Model
# print 'TheilSenRegressor'
# #print '-'*15
# TSR = TheilSenRegressor()
# TSR.fit(x_train,y_train)
# print 'Accuracy of TheilSenRegressor is %s%%'%(TSR.score(x_test,y_test)*100)
# print '='*60


# Ver Bad Model
# print 'MLPRegressor'
# #print '-'*15
# NN = MLPRegressor()
# NN.fit(x_train,y_train)
# print 'Accuracy of MLPRegressor is %s%%'%(NN.score(x_test,y_test)*100)
# print '='*60

# #AdaBooster
# print 'Ada Booster'
# #print '-'*15
# ada = AdaBoostRegressor(n_estimators=2)
# ada.fit(x_train,y_train)
# print 'Accuracy of Ada Boost is %s%%'%(ada.score(x_test,y_test)*100)
# print '='*60

# #BaggingRegressor
# print 'Bagging Regressor'
# #print '-'*15
# Bagging = BaggingRegressor(n_estimators=2)
# Bagging.fit(x_train,y_train)
# print 'Accuracy of Bagging Regressor is %s%%'%(Bagging.score(x_test,y_test)*100)
# print '='*60

# #ExtraTreesRegressor
# print 'ExtraTreesRegressor'
# #print '-'*15
# ET = ExtraTreesRegressor(n_estimators=2)
# ET.fit(x_train,y_train)
# print 'Accuracy of Extra Trees Regressor is %s%%'%(ET.score(x_test,y_test)*100)
# print '='*60

# # Very Bad 20% accuracy
# #GradientBoostingRegressor 
# print 'GradientBoostingRegressor'
# #print '-'*15
# GB = GradientBoostingRegressor(n_estimators=2)
# GB.fit(x_train,y_train)
# print 'Accuracy of Gradient Boosting Regressorr is %s%%'%(GB.score(x_test,y_test)*100)
# print '='*60

# #KernelRidge 
# print 'KernelRidge'
# #print '-'*15
# KR = KernelRidge()
# KR.fit(x_train,y_train)
# print 'Accuracy of KernelRidge Regressorr is %s%%'%(KR.score(x_test,y_test)*100)
# print '='*60

# #HuberRegressor 
# print 'HuberRegressor'
# #print '-'*15
# HR = HuberRegressor()
# HR.fit(x_train,y_train)
# print 'Accuracy of HuberRegressor is %s%%'%(HR.score(x_test,y_test)*100)
# print '='*60

# # Very Very Bad 1% accuracy
# # Why is that? 
# #LogisticRegression
# print 'LogisticRegression'
# #print '-'*15
# LogR = LogisticRegression()
# LogR.fit(x_train,y_train)
# print 'Accuracy of Logistic Regression is %s%%'%(LogR.score(x_test,y_test)*100)
# print '='*60


# Naive Bayes very bad technique as it considers the features independent of each other
